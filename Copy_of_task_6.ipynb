# %% [markdown]
# <a href="https://colab.research.google.com/github/nivikarthick/Image-Colourization/blob/main/Copy_of_task_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

cap = cv2.VideoCapture(0)

# Check if camera opened successfully
if not cap.isOpened():
    print("Error: Could not open video stream or file.")
    exit()

while True:
    ret, frame = cap.read()

    # Check if frame was read successfully
    if not ret:
        print("Error: Could not read frame from video stream. Exiting.")
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    colored = cv2.applyColorMap(gray, cv2.COLORMAP_JET)

    cv2.imshow("Colorized", colored)

    if cv2.waitKey(1)==27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Error: Could not open video stream or file.
# Error: Could not read frame from video stream. Exiting.
