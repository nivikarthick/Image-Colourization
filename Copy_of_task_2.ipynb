# %% [markdown]
# <a href="https://colab.research.google.com/github/nivikarthick/Image-Colourization/blob/main/Copy_of_task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np

def historical_tone(image, period):
    if period == "WW1":
        return cv2.applyColorMap(image, cv2.COLORMAP_BONE)
    elif period == "1920s":
        return cv2.applyColorMap(image, cv2.COLORMAP_PINK)
    return image

img = cv2.imread("input.jpg", 0)

# Check if the image was loaded successfully
if img is None:
    print("Error: Could not load 'input.jpg'. Please ensure the file exists and the path is correct.")
else:
    img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)

    period = "WW1"
    result = historical_tone(img, period)

    cv2.imwrite("output.jpg", result)
# Out:
# Error: Could not load 'input.jpg'. Please ensure the file exists and the path is correct.
